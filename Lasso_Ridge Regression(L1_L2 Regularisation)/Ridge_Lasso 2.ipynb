# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
pd.pandas.set_option('display.max_columns',None)

# %%
df=pd.read_csv('MagicBricks.csv')
df
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 0       800.0    3       2.0  Semi-Furnished
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1254   4118.0    4       5.0     Unfurnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1256    875.0    3       3.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                                Locality  Parking     Price  \
# 0                                      Rohini Sector 25      1.0   6500000
# 1                J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                   Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                      Rohini Sector 24      1.0   4200000
# ...

# %%
df.Locality.nunique()
# Out:
# 365

# %%
df.shape
# Out:
# (1259, 11)

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Furnishing       5
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
#handle NAN in Per_Sqft by mean
#parking by 0

# %%
df['Per_Sqft']=df['Per_Sqft'].fillna(np.mean(df['Per_Sqft']))
df.isnull().sum()
# Out:
# Area            0
# BHK             0
# Bathroom        2
# Furnishing      5
# Locality        0
# Parking        33
# Price           0
# Status          0
# Transaction     0
# Type            5
# Per_Sqft        0
# dtype: int64

# %%
df['Parking']=df['Parking'].fillna(0)
df.isnull().sum()
# Out:
# Area           0
# BHK            0
# Bathroom       2
# Furnishing     5
# Locality       0
# Parking        0
# Price          0
# Status         0
# Transaction    0
# Type           5
# Per_Sqft       0
# dtype: int64

# %%
col_lst=['Bathroom','Furnishing','Type']
df.drop(col_lst,axis=1,inplace=True)

# %%
df
# Out:
#          Area  BHK                                           Locality  \
# 0       800.0    3                                   Rohini Sector 25
# 1       750.0    2             J R Designers Floors, Rohini Sector 24
# 2       950.0    2                Citizen Apartment, Rohini Sector 13
# 3       600.0    2                                   Rohini Sector 24
# 4       650.0    2  Rohini Sector 24 carpet area 650 sqft status R...
# ...       ...  ...                                                ...
# 1254   4118.0    4                                  Chittaranjan Park
# 1255   1050.0    3                                  Chittaranjan Park
# 1256    875.0    3                                  Chittaranjan Park
# 1257    990.0    2                          Chittaranjan Park Block A
# 1258  11050.0    3                                  Chittaranjan Park
#
#       Parking     Price         Status   Transaction      Per_Sqft
# ...

# %%
df.isnull().sum()
# Out:
# Area           0
# BHK            0
# Locality       0
# Parking        0
# Price          0
# Status         0
# Transaction    0
# Per_Sqft       0
# dtype: int64

# %%
df.shape
# Out:
# (1259, 8)

# %%
df.head()
# Out:
#     Area  BHK                                           Locality  Parking  \
# 0  800.0    3                                   Rohini Sector 25      1.0
# 1  750.0    2             J R Designers Floors, Rohini Sector 24      1.0
# 2  950.0    2                Citizen Apartment, Rohini Sector 13      1.0
# 3  600.0    2                                   Rohini Sector 24      1.0
# 4  650.0    2  Rohini Sector 24 carpet area 650 sqft status R...      1.0
#
#       Price         Status   Transaction      Per_Sqft
# 0   6500000  Ready_to_move  New_Property  15690.136542
# 1   5000000  Ready_to_move  New_Property   6667.000000
# 2  15500000  Ready_to_move        Resale   6667.000000
# 3   4200000  Ready_to_move        Resale   6667.000000
# 4   6200000  Ready_to_move  New_Property   6667.000000

# %%
df=pd.get_dummies(df,drop_first=True)
df
# Out:
#          Area  BHK  Parking     Price      Per_Sqft  \
# 0       800.0    3      1.0   6500000  15690.136542
# 1       750.0    2      1.0   5000000   6667.000000
# 2       950.0    2      1.0  15500000   6667.000000
# 3       600.0    2      1.0   4200000   6667.000000
# 4       650.0    2      1.0   6200000   6667.000000
# ...       ...  ...      ...       ...           ...
# 1254   4118.0    4      3.0  55000000  12916.000000
# 1255   1050.0    3      3.0  12500000  12916.000000
# 1256    875.0    3      3.0  17500000  12916.000000
# 1257    990.0    2      1.0  11500000  12916.000000
# 1258  11050.0    3      1.0  18500000  12916.000000
#
#       Locality_Aashirwaad Chowk, Dwarka  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
# ...                                 ...
# 1254                                  0
# ...

# %%
x=df.drop('Price',axis=1)
y=df.Price

# %%
sc=StandardScaler()
x_scaled=sc.fit_transform(x)

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.30,random_state=1)

# %%
#Using Linear Regression
linear_model=LinearRegression()
linear_model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
linear_model.score(xtest,ytest)
# Out:
# 0.4706211650911023

# %%
linear_model.score(xtrain,ytrain)
# Out:
# 0.8174737466133453

# %%
#Using Lasso
lasso_model=Lasso(alpha=100,max_iter=100,tol=0.1)
lasso_model.fit(xtrain,ytrain)
# Out:
# Lasso(alpha=100, max_iter=100, tol=0.1)

# %%
lasso_model.score(xtest,ytest)
# Out:
# 0.61032225022069

# %%
lasso_model.score(xtrain,ytrain)
# Out:
# 0.8135068791721235

# %%
#Using Ridge
ridge_model=Ridge(alpha=50,max_iter=100,tol=0.1)
ridge_model.fit(xtrain,ytrain)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
ridge_model.score(xtrain,ytrain)
# Out:
# 0.5419463008113108

# %%
ridge_model.score(xtest,ytest)
# Out:
# 0.518440472365773
