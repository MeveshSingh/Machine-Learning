# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import random
x=np.arange(1,100,0.5)
y=np.random.normal(loc=50,scale=25,size=198)

# %%
len(y)
# Out:
# 198

# %%
len(x)
# Out:
# 198

# %%
y
# Out:
# array([ 27.97705776,  14.32206329,  33.52295935,  76.97622223,
#          6.34496718,  78.66627937,  36.18113873,  55.91218428,
#         28.88075948,  16.43218589,  14.82268   ,  -2.73376015,
#         64.0764665 ,  45.17265095,  49.88178106,  42.23252766,
#         61.84935374,  51.79374707,  23.91902949, 133.04973377,
#         26.64507529,  81.00461162,  32.94540839,  31.57182987,
#         16.30415702,  43.16849913,  68.58874038,  50.43464048,
#         55.0238145 ,  -9.05330456,  69.41966183,  55.79627661,
#         69.08078166,  59.17683503,  61.0838876 ,  52.45186689,
#         19.85976352,  49.12209559,  13.65556703,  62.55664337,
#         11.79483113,  42.92841107,  20.17411945,  38.35633345,
#         68.01858828,  22.41348579,  55.34094951,  55.06294989,
#         85.96553383,  66.07529735,  40.90669796,  63.57558393,
#         56.8673268 ,  18.44698502,  45.1714134 ,  72.97817854,
#         48.22831469,  39.38228587,  66.50811031,  80.72240959,
# ...

# %%
plt.scatter(x,y) # No linearity in data

# %%
import seaborn as sns
sns.regplot(x,y)    # u can see some linear
# Out:
# /opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
c
print('shape of ytrain:',ytrain.shape)
print('shape of ytest:',ytest.shape)
# Out:
# shape of xtrain: (138,)
# shape of xtest: (60,)
# shape of ytrain: (138,)
# shape of ytest: (60,)

# %%
xtrain.ndim
# Out:
# 1

# %%
xtrain=xtrain.reshape((-1,1))
xtest=xtest.reshape((-1,1))

# %%
print('shape of xtrain:',xtrain.shape)
print('shape of xtest:',xtest.shape)
# Out:
# shape of xtrain: (138, 1)
# shape of xtest: (60, 1)

# %%
xtrain.ndim
# Out:
# 2

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#test model
pv=model.predict(xtest)
pv
# Out:
# array([52.32485467, 47.20652346, 46.97904208, 49.10220169, 51.18744774,
#        52.59024962, 49.29176951, 45.84163514, 46.78947425, 52.02154616,
#        47.6993998 , 46.37242504, 46.10703009, 51.79406477, 51.26327487,
#        50.12586793, 49.67090516, 47.01695564, 49.86047298, 47.88896762,
#        47.62357267, 46.29659791, 47.35817772, 49.21594238, 46.86530138,
#        52.66607675, 47.13069633, 46.75156069, 52.17320041, 46.71364712,
#        47.47191841, 51.90780546, 47.92688119, 51.11162061, 51.30118843,
#        50.31543575, 50.84622566, 52.36276824, 48.64723891, 50.16378149,
#        49.74673229, 49.70881872, 47.81314049, 46.22077079, 49.97421367,
#        46.41033861, 48.45767109, 47.1686099 , 50.6945714 , 50.35334932,
#        49.25385595, 50.92205278, 52.13528685, 46.94112851, 52.74190388,
#        52.55233606, 48.8747203 , 53.15895309, 52.24902754, 48.2301897 ])

# %%
ytest
# Out:
# array([ 58.68472487,  11.79483113,  61.0838876 ,  76.00677682,
#         63.44498907,   7.7979906 ,  43.01694455,   6.34496718,
#         -9.05330456,  30.82368976,  18.44698502,  23.91902949,
#         -2.73376015,  90.11100927,  63.18612384,  37.19695963,
#        110.3576139 ,  52.45186689,  50.53522182,  66.50811031,
#         63.57558393,  61.84935374,  68.01858828,  22.0535083 ,
#         55.79627661,  66.35666277,  13.65556703,  55.0238145 ,
#         18.58600065,  50.43464048,  55.06294989,  59.90994789,
#         80.72240959,  32.69729248,  68.40709118,  77.12911808,
#         14.50125078,  55.89920647,  14.27669836,  41.09038267,
#         77.45044461,  51.9963112 ,  48.22831469,  49.88178106,
#         63.59457174, 133.04973377,  61.99655888,  62.55664337,
#         34.59959436,  43.29907474,  38.18906187,  19.32874133,
#         75.3710339 ,  59.17683503,  73.41417166,  93.21092674,
#         48.16183575,  43.3170361 ,  27.86338572,  64.23333308])

# %%
#accuracy=accuracy_score(ytest,pv)
model.score(xtest,ytest)
# Out:
# 0.00942118486802268

# %%
model.intercept_
# Out:
# 45.614153753237545

# %%
model.coef_ #slope
# Out:
# array([0.07582713])

# %%
model.score(xtest,ytest)
# Out:
# 0.00942118486802268

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
print(f'mean absolute error in model is: {mean_absolute_error(ytest,pv)}')
# Out:
# mean absolute error in model is: 21.06056270729671

# %%
print(f'square error is: {mean_squared_error(ytest,pv)}')
# Out:
# square error is: 709.5554095247196

# %%
np.sqrt(mean_squared_error(ytest,pv))
# Out:
# 26.637481290931387

# %%
plt.scatter(xtest,ytest)
plt.scatter(xtest,pv,color='r')

# %%
sns.regplot(xtest,pv)
